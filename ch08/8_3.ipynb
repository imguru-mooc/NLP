# %%
# coding: utf-8
import sys
sys.path.append('..')
sys.path.append('../ch07')
import numpy as np
import matplotlib.pyplot as plt
from dataset import sequence
from common.optimizer import Adam
from common.trainer import Trainer
from common.util import eval_seq2seq
from attention_seq2seq import AttentionSeq2seq
from ch07.seq2seq import Seq2seq
from ch07.peeky_seq2seq import PeekySeq2seq


# 데이터 읽기
(x_train, t_train), (x_test, t_test) = sequence.load_data('date.txt')
char_to_id, id_to_char = sequence.get_vocab()

# 입력 문장 반전
x_train, x_test = x_train[:, ::-1], x_test[:, ::-1]

# 하이퍼파라미터 설정
vocab_size = len(char_to_id)
wordvec_size = 16
hidden_size = 256
batch_size = 128
max_epoch = 10
max_grad = 5.0

model = AttentionSeq2seq(vocab_size, wordvec_size, hidden_size)
# model = Seq2seq(vocab_size, wordvec_size, hidden_size)
# model = PeekySeq2seq(vocab_size, wordvec_size, hidden_size)

optimizer = Adam()
trainer = Trainer(model, optimizer)

acc_list = []
for epoch in range(max_epoch):
    trainer.fit(x_train, t_train, max_epoch=1,
                batch_size=batch_size, max_grad=max_grad)

    correct_num = 0
    for i in range(len(x_test)):
        question, correct = x_test[[i]], t_test[[i]]
        verbose = i < 10
        correct_num += eval_seq2seq(model, question, correct,
                                    id_to_char, verbose, is_reverse=True)

    acc = float(correct_num) / len(x_test)
    acc_list.append(acc)
    print('정확도 %.3f%%' % (acc * 100))


model.save_params()

# 그래프 그리기
x = np.arange(len(acc_list))
plt.plot(x, acc_list, marker='o')
plt.xlabel('에폭')
plt.ylabel('정확도')
plt.ylim(-0.05, 1.05)
plt.show()
# Out:
# | 에폭 1 |  반복 1 / 351 | 시간 0[s] | 손실 4.08
# | 에폭 1 |  반복 21 / 351 | 시간 6[s] | 손실 3.09
# | 에폭 1 |  반복 41 / 351 | 시간 11[s] | 손실 1.90
# | 에폭 1 |  반복 61 / 351 | 시간 17[s] | 손실 1.72
# | 에폭 1 |  반복 81 / 351 | 시간 23[s] | 손실 1.46
# | 에폭 1 |  반복 101 / 351 | 시간 29[s] | 손실 1.19
# | 에폭 1 |  반복 121 / 351 | 시간 35[s] | 손실 1.14
# | 에폭 1 |  반복 141 / 351 | 시간 40[s] | 손실 1.09
# | 에폭 1 |  반복 161 / 351 | 시간 46[s] | 손실 1.06
# | 에폭 1 |  반복 181 / 351 | 시간 51[s] | 손실 1.04
# | 에폭 1 |  반복 201 / 351 | 시간 56[s] | 손실 1.03
# | 에폭 1 |  반복 221 / 351 | 시간 62[s] | 손실 1.02
# | 에폭 1 |  반복 241 / 351 | 시간 67[s] | 손실 1.02
# | 에폭 1 |  반복 261 / 351 | 시간 72[s] | 손실 1.01
# | 에폭 1 |  반복 281 / 351 | 시간 78[s] | 손실 1.00
# | 에폭 1 |  반복 301 / 351 | 시간 83[s] | 손실 1.00
# | 에폭 1 |  반복 321 / 351 | 시간 88[s] | 손실 1.00
# | 에폭 1 |  반복 341 / 351 | 시간 94[s] | 손실 1.00
# Q 10/15/94
# T 1994-10-15
# X 1978-08-11
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# X 1978-08-11
# ---
# Q Mar 25, 2003
# T 2003-03-25
# X 1978-08-11
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# X 1978-08-11
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# X 1978-08-11
# ---
# Q october 6, 1992
# T 1992-10-06
# X 1978-08-11
# ---
# Q 8/23/08
# T 2008-08-23
# X 1978-08-11
# ---
# Q 8/30/07
# T 2007-08-30
# X 1978-08-11
# ---
# Q 10/28/13
# T 2013-10-28
# X 1978-08-11
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# X 1978-08-11
# ---
# 정확도 0.000%
# | 에폭 2 |  반복 1 / 351 | 시간 0[s] | 손실 1.00
# | 에폭 2 |  반복 21 / 351 | 시간 5[s] | 손실 1.00
# | 에폭 2 |  반복 41 / 351 | 시간 10[s] | 손실 0.99
# | 에폭 2 |  반복 61 / 351 | 시간 15[s] | 손실 0.99
# | 에폭 2 |  반복 81 / 351 | 시간 20[s] | 손실 0.99
# | 에폭 2 |  반복 101 / 351 | 시간 25[s] | 손실 0.99
# | 에폭 2 |  반복 121 / 351 | 시간 31[s] | 손실 0.99
# | 에폭 2 |  반복 141 / 351 | 시간 36[s] | 손실 0.98
# | 에폭 2 |  반복 161 / 351 | 시간 41[s] | 손실 0.98
# | 에폭 2 |  반복 181 / 351 | 시간 46[s] | 손실 0.97
# | 에폭 2 |  반복 201 / 351 | 시간 51[s] | 손실 0.95
# | 에폭 2 |  반복 221 / 351 | 시간 56[s] | 손실 0.94
# | 에폭 2 |  반복 241 / 351 | 시간 61[s] | 손실 0.90
# | 에폭 2 |  반복 261 / 351 | 시간 66[s] | 손실 0.83
# | 에폭 2 |  반복 281 / 351 | 시간 71[s] | 손실 0.74
# | 에폭 2 |  반복 301 / 351 | 시간 76[s] | 손실 0.66
# | 에폭 2 |  반복 321 / 351 | 시간 81[s] | 손실 0.58
# | 에폭 2 |  반복 341 / 351 | 시간 87[s] | 손실 0.46
# Q 10/15/94
# T 1994-10-15
# O 1994-10-15
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# X 2006-11-13
# ---
# Q Mar 25, 2003
# T 2003-03-25
# O 2003-03-25
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# O 2016-11-22
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# O 1970-07-18
# ---
# Q october 6, 1992
# T 1992-10-06
# O 1992-10-06
# ---
# Q 8/23/08
# T 2008-08-23
# O 2008-08-23
# ---
# Q 8/30/07
# T 2007-08-30
# X 2007-08-09
# ---
# Q 10/28/13
# T 2013-10-28
# X 1983-10-28
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# X 2016-11-08
# ---
# 정확도 51.540%
# | 에폭 3 |  반복 1 / 351 | 시간 0[s] | 손실 0.35
# | 에폭 3 |  반복 21 / 351 | 시간 5[s] | 손실 0.30
# | 에폭 3 |  반복 41 / 351 | 시간 10[s] | 손실 0.21
# | 에폭 3 |  반복 61 / 351 | 시간 15[s] | 손실 0.14
# | 에폭 3 |  반복 81 / 351 | 시간 20[s] | 손실 0.09
# | 에폭 3 |  반복 101 / 351 | 시간 25[s] | 손실 0.07
# | 에폭 3 |  반복 121 / 351 | 시간 31[s] | 손실 0.05
# | 에폭 3 |  반복 141 / 351 | 시간 36[s] | 손실 0.04
# | 에폭 3 |  반복 161 / 351 | 시간 41[s] | 손실 0.03
# | 에폭 3 |  반복 181 / 351 | 시간 46[s] | 손실 0.03
# | 에폭 3 |  반복 201 / 351 | 시간 51[s] | 손실 0.02
# | 에폭 3 |  반복 221 / 351 | 시간 57[s] | 손실 0.02
# | 에폭 3 |  반복 241 / 351 | 시간 62[s] | 손실 0.02
# | 에폭 3 |  반복 261 / 351 | 시간 67[s] | 손실 0.01
# | 에폭 3 |  반복 281 / 351 | 시간 72[s] | 손실 0.01
# | 에폭 3 |  반복 301 / 351 | 시간 77[s] | 손실 0.01
# | 에폭 3 |  반복 321 / 351 | 시간 82[s] | 손실 0.01
# | 에폭 3 |  반복 341 / 351 | 시간 88[s] | 손실 0.01
# Q 10/15/94
# T 1994-10-15
# O 1994-10-15
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# O 2008-11-13
# ---
# Q Mar 25, 2003
# T 2003-03-25
# O 2003-03-25
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# O 2016-11-22
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# O 1970-07-18
# ---
# Q october 6, 1992
# T 1992-10-06
# O 1992-10-06
# ---
# Q 8/23/08
# T 2008-08-23
# O 2008-08-23
# ---
# Q 8/30/07
# T 2007-08-30
# O 2007-08-30
# ---
# Q 10/28/13
# T 2013-10-28
# O 2013-10-28
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# O 2016-11-06
# ---
# 정확도 99.900%
# | 에폭 4 |  반복 1 / 351 | 시간 0[s] | 손실 0.01
# | 에폭 4 |  반복 21 / 351 | 시간 5[s] | 손실 0.01
# | 에폭 4 |  반복 41 / 351 | 시간 10[s] | 손실 0.01
# | 에폭 4 |  반복 61 / 351 | 시간 15[s] | 손실 0.01
# | 에폭 4 |  반복 81 / 351 | 시간 20[s] | 손실 0.01
# | 에폭 4 |  반복 101 / 351 | 시간 26[s] | 손실 0.01
# | 에폭 4 |  반복 121 / 351 | 시간 31[s] | 손실 0.00
# | 에폭 4 |  반복 141 / 351 | 시간 36[s] | 손실 0.01
# | 에폭 4 |  반복 161 / 351 | 시간 41[s] | 손실 0.00
# | 에폭 4 |  반복 181 / 351 | 시간 46[s] | 손실 0.00
# | 에폭 4 |  반복 201 / 351 | 시간 51[s] | 손실 0.00
# | 에폭 4 |  반복 221 / 351 | 시간 57[s] | 손실 0.00
# | 에폭 4 |  반복 241 / 351 | 시간 62[s] | 손실 0.00
# | 에폭 4 |  반복 261 / 351 | 시간 67[s] | 손실 0.00
# | 에폭 4 |  반복 281 / 351 | 시간 72[s] | 손실 0.01
# | 에폭 4 |  반복 301 / 351 | 시간 77[s] | 손실 0.00
# | 에폭 4 |  반복 321 / 351 | 시간 82[s] | 손실 0.00
# | 에폭 4 |  반복 341 / 351 | 시간 87[s] | 손실 0.00
# Q 10/15/94
# T 1994-10-15
# O 1994-10-15
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# O 2008-11-13
# ---
# Q Mar 25, 2003
# T 2003-03-25
# O 2003-03-25
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# O 2016-11-22
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# O 1970-07-18
# ---
# Q october 6, 1992
# T 1992-10-06
# O 1992-10-06
# ---
# Q 8/23/08
# T 2008-08-23
# O 2008-08-23
# ---
# Q 8/30/07
# T 2007-08-30
# O 2007-08-30
# ---
# Q 10/28/13
# T 2013-10-28
# O 2013-10-28
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# O 2016-11-06
# ---
# 정확도 99.900%
# | 에폭 5 |  반복 1 / 351 | 시간 0[s] | 손실 0.00
# | 에폭 5 |  반복 21 / 351 | 시간 5[s] | 손실 0.00
# | 에폭 5 |  반복 41 / 351 | 시간 10[s] | 손실 0.00
# | 에폭 5 |  반복 61 / 351 | 시간 15[s] | 손실 0.00
# | 에폭 5 |  반복 81 / 351 | 시간 20[s] | 손실 0.00
# | 에폭 5 |  반복 101 / 351 | 시간 25[s] | 손실 0.00
# | 에폭 5 |  반복 121 / 351 | 시간 31[s] | 손실 0.00
# | 에폭 5 |  반복 141 / 351 | 시간 36[s] | 손실 0.00
# | 에폭 5 |  반복 161 / 351 | 시간 41[s] | 손실 0.00
# | 에폭 5 |  반복 181 / 351 | 시간 46[s] | 손실 0.00
# | 에폭 5 |  반복 201 / 351 | 시간 51[s] | 손실 0.00
# | 에폭 5 |  반복 221 / 351 | 시간 56[s] | 손실 0.00
# | 에폭 5 |  반복 241 / 351 | 시간 61[s] | 손실 0.00
# | 에폭 5 |  반복 261 / 351 | 시간 66[s] | 손실 0.00
# | 에폭 5 |  반복 281 / 351 | 시간 71[s] | 손실 0.00
# | 에폭 5 |  반복 301 / 351 | 시간 77[s] | 손실 0.00
# | 에폭 5 |  반복 321 / 351 | 시간 82[s] | 손실 0.00
# | 에폭 5 |  반복 341 / 351 | 시간 87[s] | 손실 0.00
# Q 10/15/94
# T 1994-10-15
# O 1994-10-15
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# O 2008-11-13
# ---
# Q Mar 25, 2003
# T 2003-03-25
# O 2003-03-25
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# O 2016-11-22
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# O 1970-07-18
# ---
# Q october 6, 1992
# T 1992-10-06
# O 1992-10-06
# ---
# Q 8/23/08
# T 2008-08-23
# O 2008-08-23
# ---
# Q 8/30/07
# T 2007-08-30
# O 2007-08-30
# ---
# Q 10/28/13
# T 2013-10-28
# O 2013-10-28
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# O 2016-11-06
# ---
# 정확도 99.920%
# | 에폭 6 |  반복 1 / 351 | 시간 0[s] | 손실 0.00
# | 에폭 6 |  반복 21 / 351 | 시간 5[s] | 손실 0.00
# | 에폭 6 |  반복 41 / 351 | 시간 10[s] | 손실 0.00
# | 에폭 6 |  반복 61 / 351 | 시간 15[s] | 손실 0.00
# | 에폭 6 |  반복 81 / 351 | 시간 20[s] | 손실 0.00
# | 에폭 6 |  반복 101 / 351 | 시간 25[s] | 손실 0.00
# | 에폭 6 |  반복 121 / 351 | 시간 31[s] | 손실 0.00
# | 에폭 6 |  반복 141 / 351 | 시간 36[s] | 손실 0.00
# | 에폭 6 |  반복 161 / 351 | 시간 41[s] | 손실 0.00
# | 에폭 6 |  반복 181 / 351 | 시간 46[s] | 손실 0.00
# | 에폭 6 |  반복 201 / 351 | 시간 51[s] | 손실 0.00
# | 에폭 6 |  반복 221 / 351 | 시간 56[s] | 손실 0.00
# | 에폭 6 |  반복 241 / 351 | 시간 61[s] | 손실 0.00
# | 에폭 6 |  반복 261 / 351 | 시간 66[s] | 손실 0.00
# | 에폭 6 |  반복 281 / 351 | 시간 72[s] | 손실 0.00
# | 에폭 6 |  반복 301 / 351 | 시간 77[s] | 손실 0.00
# | 에폭 6 |  반복 321 / 351 | 시간 82[s] | 손실 0.00
# | 에폭 6 |  반복 341 / 351 | 시간 87[s] | 손실 0.00
# Q 10/15/94
# T 1994-10-15
# O 1994-10-15
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# O 2008-11-13
# ---
# Q Mar 25, 2003
# T 2003-03-25
# O 2003-03-25
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# O 2016-11-22
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# O 1970-07-18
# ---
# Q october 6, 1992
# T 1992-10-06
# O 1992-10-06
# ---
# Q 8/23/08
# T 2008-08-23
# O 2008-08-23
# ---
# Q 8/30/07
# T 2007-08-30
# O 2007-08-30
# ---
# Q 10/28/13
# T 2013-10-28
# O 2013-10-28
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# O 2016-11-06
# ---
# 정확도 99.920%
# | 에폭 7 |  반복 1 / 351 | 시간 0[s] | 손실 0.00
# | 에폭 7 |  반복 21 / 351 | 시간 5[s] | 손실 0.00
# | 에폭 7 |  반복 41 / 351 | 시간 10[s] | 손실 0.00
# | 에폭 7 |  반복 61 / 351 | 시간 15[s] | 손실 0.00
# | 에폭 7 |  반복 81 / 351 | 시간 20[s] | 손실 0.00
# | 에폭 7 |  반복 101 / 351 | 시간 25[s] | 손실 0.00
# | 에폭 7 |  반복 121 / 351 | 시간 30[s] | 손실 0.00
# | 에폭 7 |  반복 141 / 351 | 시간 35[s] | 손실 0.00
# | 에폭 7 |  반복 161 / 351 | 시간 40[s] | 손실 0.00
# | 에폭 7 |  반복 181 / 351 | 시간 45[s] | 손실 0.00
# | 에폭 7 |  반복 201 / 351 | 시간 51[s] | 손실 0.00
# | 에폭 7 |  반복 221 / 351 | 시간 56[s] | 손실 0.00
# | 에폭 7 |  반복 241 / 351 | 시간 61[s] | 손실 0.00
# | 에폭 7 |  반복 261 / 351 | 시간 66[s] | 손실 0.00
# | 에폭 7 |  반복 281 / 351 | 시간 71[s] | 손실 0.00
# | 에폭 7 |  반복 301 / 351 | 시간 76[s] | 손실 0.00
# | 에폭 7 |  반복 321 / 351 | 시간 82[s] | 손실 0.00
# | 에폭 7 |  반복 341 / 351 | 시간 87[s] | 손실 0.00
# Q 10/15/94
# T 1994-10-15
# O 1994-10-15
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# O 2008-11-13
# ---
# Q Mar 25, 2003
# T 2003-03-25
# O 2003-03-25
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# O 2016-11-22
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# O 1970-07-18
# ---
# Q october 6, 1992
# T 1992-10-06
# O 1992-10-06
# ---
# Q 8/23/08
# T 2008-08-23
# O 2008-08-23
# ---
# Q 8/30/07
# T 2007-08-30
# O 2007-08-30
# ---
# Q 10/28/13
# T 2013-10-28
# O 2013-10-28
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# O 2016-11-06
# ---
# 정확도 99.920%
# | 에폭 8 |  반복 1 / 351 | 시간 0[s] | 손실 0.00
# | 에폭 8 |  반복 21 / 351 | 시간 5[s] | 손실 0.00
# | 에폭 8 |  반복 41 / 351 | 시간 10[s] | 손실 0.00
# | 에폭 8 |  반복 61 / 351 | 시간 15[s] | 손실 0.00
# | 에폭 8 |  반복 81 / 351 | 시간 20[s] | 손실 0.00
# | 에폭 8 |  반복 101 / 351 | 시간 26[s] | 손실 0.00
# | 에폭 8 |  반복 121 / 351 | 시간 31[s] | 손실 0.00
# | 에폭 8 |  반복 141 / 351 | 시간 36[s] | 손실 0.00
# | 에폭 8 |  반복 161 / 351 | 시간 41[s] | 손실 0.00
# | 에폭 8 |  반복 181 / 351 | 시간 46[s] | 손실 0.00
# | 에폭 8 |  반복 201 / 351 | 시간 51[s] | 손실 0.00
# | 에폭 8 |  반복 221 / 351 | 시간 56[s] | 손실 0.00
# | 에폭 8 |  반복 241 / 351 | 시간 62[s] | 손실 0.00
# | 에폭 8 |  반복 261 / 351 | 시간 67[s] | 손실 0.00
# | 에폭 8 |  반복 281 / 351 | 시간 72[s] | 손실 0.00
# | 에폭 8 |  반복 301 / 351 | 시간 77[s] | 손실 0.00
# | 에폭 8 |  반복 321 / 351 | 시간 82[s] | 손실 0.00
# | 에폭 8 |  반복 341 / 351 | 시간 87[s] | 손실 0.00
# Q 10/15/94
# T 1994-10-15
# O 1994-10-15
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# O 2008-11-13
# ---
# Q Mar 25, 2003
# T 2003-03-25
# O 2003-03-25
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# O 2016-11-22
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# O 1970-07-18
# ---
# Q october 6, 1992
# T 1992-10-06
# O 1992-10-06
# ---
# Q 8/23/08
# T 2008-08-23
# O 2008-08-23
# ---
# Q 8/30/07
# T 2007-08-30
# O 2007-08-30
# ---
# Q 10/28/13
# T 2013-10-28
# O 2013-10-28
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# O 2016-11-06
# ---
# 정확도 99.920%
# | 에폭 9 |  반복 1 / 351 | 시간 0[s] | 손실 0.00
# | 에폭 9 |  반복 21 / 351 | 시간 5[s] | 손실 0.00
# | 에폭 9 |  반복 41 / 351 | 시간 10[s] | 손실 0.00
# | 에폭 9 |  반복 61 / 351 | 시간 15[s] | 손실 0.00
# | 에폭 9 |  반복 81 / 351 | 시간 20[s] | 손실 0.00
# | 에폭 9 |  반복 101 / 351 | 시간 25[s] | 손실 0.00
# | 에폭 9 |  반복 121 / 351 | 시간 31[s] | 손실 0.00
# | 에폭 9 |  반복 141 / 351 | 시간 36[s] | 손실 0.00
# | 에폭 9 |  반복 161 / 351 | 시간 41[s] | 손실 0.00
# | 에폭 9 |  반복 181 / 351 | 시간 46[s] | 손실 0.00
# | 에폭 9 |  반복 201 / 351 | 시간 51[s] | 손실 0.00
# | 에폭 9 |  반복 221 / 351 | 시간 56[s] | 손실 0.00
# | 에폭 9 |  반복 241 / 351 | 시간 61[s] | 손실 0.00
# | 에폭 9 |  반복 261 / 351 | 시간 66[s] | 손실 0.00
# | 에폭 9 |  반복 281 / 351 | 시간 72[s] | 손실 0.00
# | 에폭 9 |  반복 301 / 351 | 시간 77[s] | 손실 0.00
# | 에폭 9 |  반복 321 / 351 | 시간 82[s] | 손실 0.00
# | 에폭 9 |  반복 341 / 351 | 시간 87[s] | 손실 0.00
# Q 10/15/94
# T 1994-10-15
# O 1994-10-15
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# O 2008-11-13
# ---
# Q Mar 25, 2003
# T 2003-03-25
# O 2003-03-25
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# O 2016-11-22
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# O 1970-07-18
# ---
# Q october 6, 1992
# T 1992-10-06
# O 1992-10-06
# ---
# Q 8/23/08
# T 2008-08-23
# O 2008-08-23
# ---
# Q 8/30/07
# T 2007-08-30
# O 2007-08-30
# ---
# Q 10/28/13
# T 2013-10-28
# O 2013-10-28
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# O 2016-11-06
# ---
# 정확도 99.960%
# | 에폭 10 |  반복 1 / 351 | 시간 0[s] | 손실 0.00
# | 에폭 10 |  반복 21 / 351 | 시간 5[s] | 손실 0.00
# | 에폭 10 |  반복 41 / 351 | 시간 10[s] | 손실 0.00
# | 에폭 10 |  반복 61 / 351 | 시간 15[s] | 손실 0.00
# | 에폭 10 |  반복 81 / 351 | 시간 20[s] | 손실 0.00
# | 에폭 10 |  반복 101 / 351 | 시간 26[s] | 손실 0.00
# | 에폭 10 |  반복 121 / 351 | 시간 31[s] | 손실 0.00
# | 에폭 10 |  반복 141 / 351 | 시간 36[s] | 손실 0.00
# | 에폭 10 |  반복 161 / 351 | 시간 41[s] | 손실 0.00
# | 에폭 10 |  반복 181 / 351 | 시간 46[s] | 손실 0.00
# | 에폭 10 |  반복 201 / 351 | 시간 51[s] | 손실 0.00
# | 에폭 10 |  반복 221 / 351 | 시간 56[s] | 손실 0.00
# | 에폭 10 |  반복 241 / 351 | 시간 62[s] | 손실 0.00
# | 에폭 10 |  반복 261 / 351 | 시간 67[s] | 손실 0.00
# | 에폭 10 |  반복 281 / 351 | 시간 72[s] | 손실 0.00
# | 에폭 10 |  반복 301 / 351 | 시간 77[s] | 손실 0.00
# | 에폭 10 |  반복 321 / 351 | 시간 82[s] | 손실 0.00
# | 에폭 10 |  반복 341 / 351 | 시간 87[s] | 손실 0.00
# Q 10/15/94
# T 1994-10-15
# O 1994-10-15
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# O 2008-11-13
# ---
# Q Mar 25, 2003
# T 2003-03-25
# O 2003-03-25
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# O 2016-11-22
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# O 1970-07-18
# ---
# Q october 6, 1992
# T 1992-10-06
# O 1992-10-06
# ---
# Q 8/23/08
# T 2008-08-23
# O 2008-08-23
# ---
# Q 8/30/07
# T 2007-08-30
# O 2007-08-30
# ---
# Q 10/28/13
# T 2013-10-28
# O 2013-10-28
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# O 2016-11-06
# ---
# 정확도 99.960%
# C:\Users\jikim\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 50640 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\jikim\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 54253 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\jikim\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51221 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\jikim\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 54869 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\jikim\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\jikim\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 50640 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\jikim\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 54253 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\jikim\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51221 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\jikim\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 54869 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\jikim\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
# coding: utf-8
import sys
sys.path.append('..')
import numpy as np
from dataset import sequence
import matplotlib.pyplot as plt
from attention_seq2seq import AttentionSeq2seq


(x_train, t_train), (x_test, t_test) = \
    sequence.load_data('date.txt')
char_to_id, id_to_char = sequence.get_vocab()

# 입력 문장 반전
x_train, x_test = x_train[:, ::-1], x_test[:, ::-1]

vocab_size = len(char_to_id)
wordvec_size = 16
hidden_size = 256

model = AttentionSeq2seq(vocab_size, wordvec_size, hidden_size)
model.load_params()

_idx = 0
def visualize(attention_map, row_labels, column_labels):
    fig, ax = plt.subplots()
    ax.pcolor(attention_map, cmap=plt.cm.Greys_r, vmin=0.0, vmax=1.0)

    ax.patch.set_facecolor('black')
    ax.set_yticks(np.arange(attention_map.shape[0])+0.5, minor=False)
    ax.set_xticks(np.arange(attention_map.shape[1])+0.5, minor=False)
    ax.invert_yaxis()
    ax.set_xticklabels(row_labels, minor=False)
    ax.set_yticklabels(column_labels, minor=False)

    global _idx
    _idx += 1
    plt.show()


np.random.seed(1984)
for _ in range(5):
    idx = [np.random.randint(0, len(x_test))]
    x = x_test[idx]
    t = t_test[idx]

    model.forward(x, t)
    d = model.decoder.attention.attention_weights
    d = np.array(d)
    attention_map = d.reshape(d.shape[0], d.shape[2])

    # 출력하기 위해 반전
    attention_map = attention_map[:,::-1]
    x = x[:,::-1]

    row_labels = [id_to_char[i] for i in x[0]]
    column_labels = [id_to_char[i] for i in t[0]]
    column_labels = column_labels[1:]

    visualize(attention_map, row_labels, column_labels)
